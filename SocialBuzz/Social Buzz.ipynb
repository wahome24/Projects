# %% [markdown]
# #### The purpose of the below code is to analyse the top five content categories based on reaction score.

# %%
import numpy as np
import pandas as pd

# %%
#Importing dataset

content = pd.read_csv(r"C:\Users\USER\Desktop\Virtual Internships\Data.csv")

# %%
#Displaying the data

content
# Out:
#                                  Content ID        Type  Reaction Score  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust               0
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike              10
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2      scared              15
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust               0
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2  interested              30
# ...                                     ...         ...             ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike              10
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued              45
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56  interested              30
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56     worried              12
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish              70
#
#          Category
# 0        Studying
# 1        Studying
# 2        Studying
# 3        Studying
# ...

# %%
#Updating the Type column name

content.columns
# Out:
# Index(['Content ID', 'Type', 'Reaction Score', 'Category'], dtype='object')

# %%
content.columns = ['Content ID', 'Reaction Type', 'Reaction Score', 'Category']

# %%
content
# Out:
#                                  Content ID Reaction Type  Reaction Score  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust               0
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike              10
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared              15
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust               0
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested              30
# ...                                     ...           ...             ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike              10
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued              45
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested              30
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried              12
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish              70
#
#          Category
# 0        Studying
# 1        Studying
# 2        Studying
# ...

# %%
#New dataframe to store relevant columns for our analysis

df = content[['Category','Reaction Type','Reaction Score']]

# %%
df
# Out:
#          Category Reaction Type  Reaction Score
# 0        Studying       disgust               0
# 1        Studying       dislike              10
# 2        Studying        scared              15
# 3        Studying       disgust               0
# 4        Studying    interested              30
# ...           ...           ...             ...
# 24568  technology       dislike              10
# 24569  technology     intrigued              45
# 24570  technology    interested              30
# 24571  technology       worried              12
# 24572  technology       cherish              70
#
# [24573 rows x 3 columns]

# %%
#Checking column data types

df.dtypes
# Out:
# Category          object
# Reaction Type     object
# Reaction Score     int64
# dtype: object

# %%
df['Category1']= df['Category'].str.lower()

# %%
df
# Out:
#          Category Reaction Type  Reaction Score   Category1
# 0        studying       disgust               0    studying
# 1        studying       dislike              10    studying
# 2        studying        scared              15    studying
# 3        studying       disgust               0    studying
# 4        studying    interested              30    studying
# ...           ...           ...             ...         ...
# 24568  technology       dislike              10  technology
# 24569  technology     intrigued              45  technology
# 24570  technology    interested              30  technology
# 24571  technology       worried              12  technology
# 24572  technology       cherish              70  technology
#
# [24573 rows x 4 columns]

# %%
#Calculating total review scores for each category

df.groupby('Category1')['Reaction Score'].sum()
# Out:
# Category1
# "animals"             1694
# "cooking"              774
# "culture"             2037
# "dogs"                1763
# "food"                  50
# "public speaking"      979
# "science"              506
# "soccer"              2468
# "studying"             546
# "technology"          1049
# "veganism"            1129
# animals              73271
# cooking              63982
# culture              64542
# dogs                 50748
# education            57436
# fitness              55323
# food                 66626
# healthy eating       69339
# public speaking      48285
# science              70662
# soccer               55315
# studying             53723
# technology           67689
# tennis               50339
# travel               64880
# veganism             48490
# Name: Reaction Score, dtype: int64

# %%
#Storing the grouped categories as a data frame in order to perform sorting

result = pd.DataFrame(df.groupby('Category')['Reaction Score'].sum())

# %%
result
# Out:
#                    Reaction Score
# Category
# "animals"                    1694
# "cooking"                     774
# "culture"                    2037
# "dogs"                       1763
# "food"                         50
# "public speaking"             979
# "science"                     506
# "soccer"                     2468
# "studying"                    546
# "technology"                 1049
# "veganism"                   1129
# animals                     73271
# cooking                     63982
# culture                     64542
# dogs                        50748
# education                   57436
# fitness                     55323
# food                        66626
# healthy eating              69339
# public speaking             48285
# science                     70662
# soccer                      55315
# studying                    53723
# technology                  67689
# tennis                      50339
# travel                      64880
# ...

# %%
top_five = result.sort_values('Reaction Score', ascending = False )

# %%
#Top five categories

top_five.head()
# Out:
#                 Reaction Score
# Category
# animals                  73271
# science                  70662
# healthy eating           69339
# technology               67689
# food                     66626
